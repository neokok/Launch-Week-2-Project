# %% [markdown]
# ## THIS NOTEBOOK WILL NOT WORK IN GOOGLE COLAB!!! IT MUST BE RUN LOCALLY!!! You can download it as an .ipynb file and open that with Jupyter notebook/labs

# %%
# !pip install pymysql
# !pip install sqlalchemy

import sqlalchemy
import pymysql
from sqlalchemy import create_engine
import pandas as pd

# %% [markdown]
# If you get an error saying something like "sqlalchemy not installed", you should add a code cell and write `pip install sqlalchemy`. Then, rerun the above cell (you might also need to install pymysql the same way)

# %%
password = 'Silverhorse$1'
db_name = 'songs'

# %%
conn = pymysql.connect(host='127.0.0.1', port=3306, user='root', password=password, database=db_name)

# %%
connection = create_engine("mysql+pymysql://root:" + password + "@localhost:3306/" + db_name)

# %%
song = pd.read_csv('/Users/ellathomasson/Downloads/Project 2 - Songs (2).csv')
artist = pd.read_csv('/Users/ellathomasson/Downloads/Project 2 - Artists.csv')
album = pd.read_csv('/Users/ellathomasson/Downloads/Project 2 - Albums.csv')
playlist = pd.read_csv('/Users/ellathomasson/Downloads/Project 2 - Playlists.csv')
user = pd.read_csv('/Users/ellathomasson/Downloads/Project 2 - Users (1).csv')

# %%
# Out:
# 59

# %%
table_name1 = 'Song'
table_name2 = 'Artists'
table_name3 = 'Albums'
table_name4 = 'Playlists'
table_name5 = 'Users'

# %%
song.to_sql(name=table_name1, con=connection, if_exists='replace', index=False)
artist.to_sql(name=table_name2, con=connection, if_exists='replace', index=False)
album.to_sql(name=table_name3, con=connection, if_exists='replace', index=False)
playlist.to_sql(name=table_name4, con=connection, if_exists='replace', index=False)
user.to_sql(name=table_name5, con=connection, if_exists='replace', index=False)
# Out:
# 10

# %% [markdown]
# We use SQL syntax for querying. The triple quotation mark syntax allows us to write commands simiar to how we did in SQL

# %%
query1 = "SELECT * FROM songs"
query2 = """

SELECT * FROM facts
WHERE Title ='Happier'

"""

# %%
result_df = pd.read_sql(query1, con=connection)

# %%
result_df
# Out:
#     Song_ID                       Title  Artist_ID  Album_ID  Playlist_ID  \
# 0         1                     Happier        1.0       1.0          1.0
# 1         2              Enough for You        1.0       1.0          4.0
# 2         3                     Deja Vu        1.0       1.0          7.0
# 3         4                      Brutal        1.0       1.0         10.0
# 4         5                Kiss Me More        9.0       7.0          5.0
# 5         6              American Idiot        3.0       8.0          8.0
# 6         7  Boulevard of Broken Dreams        3.0       8.0         10.0
# 7         8                  Homecoming        3.0       8.0          9.0
# 8         9                     Golden         8.0       2.0          1.0
# 9        10                   Adore You        8.0       2.0          5.0
# 10       11               Love to Dream        9.0       7.0          1.0
# 11       12         When We Were Young         NaN       NaN          4.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
# ...

# %%
result_df_2

# %% [markdown]
# We can merge in PyMySQL just like in regular SQL

# %%
df2 = pd.DataFrame({'_id':[1,2,3] , 'Is_Primary':[False,True,False], 'Hex_Code':['#A020F0', '#0000FF', '#00FF00']})
df2

# %%
df2.to_sql(name='color_table', con=connection, if_exists='replace', index=False)

# %%
query3 = """
  SELECT facts.Names, facts.Favorite_Color, color_table.Is_Primary, color_table.Hex_Code
  FROM facts
  LEFT JOIN color_table ON facts.Favorite_Color = color_table.Colors
"""

# %%
result_df_3 = pd.read_sql(query3, con=connection)

# %%
result_df_3
